# %%
# !pip install geopandas
# Out:
# Requirement already satisfied: geopandas in c:\users\dell\miniconda3\lib\site-packages (0.14.2)
# Requirement already satisfied: pandas>=1.4.0 in c:\users\dell\miniconda3\lib\site-packages (from geopandas) (1.5.2)
# Requirement already satisfied: fiona>=1.8.21 in c:\users\dell\miniconda3\lib\site-packages (from geopandas) (1.9.5)
# Requirement already satisfied: shapely>=1.8.0 in c:\users\dell\miniconda3\lib\site-packages (from geopandas) (1.8.5.post1)
# Requirement already satisfied: packaging in c:\users\dell\miniconda3\lib\site-packages (from geopandas) (21.3)
# Requirement already satisfied: pyproj>=3.3.0 in c:\users\dell\miniconda3\lib\site-packages (from geopandas) (3.6.1)
# Requirement already satisfied: click~=8.0 in c:\users\dell\miniconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (8.0.3)
# Requirement already satisfied: importlib-metadata in c:\users\dell\miniconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (4.11.4)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\dell\miniconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (22.1.0)
# Requirement already satisfied: setuptools in c:\users\dell\miniconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (58.3.0)
# Requirement already satisfied: certifi in c:\users\dell\miniconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (2021.10.8)
# Requirement already satisfied: cligj>=0.5 in c:\users\dell\miniconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (0.7.2)
# Requirement already satisfied: six in c:\users\dell\miniconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (1.16.0)
# Requirement already satisfied: click-plugins>=1.0 in c:\users\dell\miniconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (1.1.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dell\miniconda3\lib\site-packages (from pandas>=1.4.0->geopandas) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\dell\miniconda3\lib\site-packages (from pandas>=1.4.0->geopandas) (2.8.2)
# Requirement already satisfied: numpy>=1.20.3 in c:\users\dell\miniconda3\lib\site-packages (from pandas>=1.4.0->geopandas) (1.21.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\dell\miniconda3\lib\site-packages (from packaging->geopandas) (3.0.9)
# Requirement already satisfied: colorama in c:\users\dell\miniconda3\lib\site-packages (from click~=8.0->fiona>=1.8.21->geopandas) (0.4.4)
# Requirement already satisfied: zipp>=0.5 in c:\users\dell\miniconda3\lib\site-packages (from importlib-metadata->fiona>=1.8.21->geopandas) (3.8.1)
# [notice] A new release of pip available: 22.2.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import geopandas as gpd
import pandas as pd

# %%
shape = gpd.read_file('../data/poligonos_alcaldias_cdmx/poligonos_alcaldias_cdmx.shp')
shape
# Out:
#    CVEGEO CVE_ENT CVE_MUN                  NOMGEO  \
# 0   09002      09     002            Azcapotzalco
# 1   09003      09     003                Coyoacán
# 2   09004      09     004   Cuajimalpa de Morelos
# 3   09005      09     005       Gustavo A. Madero
# 4   09006      09     006               Iztacalco
# 5   09007      09     007              Iztapalapa
# 6   09008      09     008  La Magdalena Contreras
# 7   09009      09     009              Milpa Alta
# 8   09010      09     010          Álvaro Obregón
# 9   09011      09     011                 Tláhuac
# 10  09012      09     012                 Tlalpan
# 11  09013      09     013              Xochimilco
# 12  09014      09     014           Benito Juárez
# 13  09015      09     015              Cuauhtémoc
# 14  09016      09     016          Miguel Hidalgo
# 15  09017      09     017     Venustiano Carranza
#
#                                              geometry
# 0   POLYGON ((-99.18231 19.50748, -99.18229 19.507...
# 1   POLYGON ((-99.13427 19.35654, -99.13397 19.356...
# 2   POLYGON ((-99.25738 19.40112, -99.25698 19.400...
# 3   POLYGON ((-99.11124 19.56150, -99.11485 19.557...
# 4   POLYGON ((-99.05751 19.40673, -99.05753 19.406...
# 5   POLYGON ((-99.01692 19.38187, -99.01652 19.381...
# 6   POLYGON ((-99.20819 19.33674, -99.20859 19.336...
# 7   POLYGON ((-98.99718 19.22747, -98.99723 19.227...
# 8   POLYGON ((-99.18906 19.39559, -99.18871 19.394...
# 9   POLYGON ((-98.97881 19.32392, -98.97856 19.323...
# 10  POLYGON ((-99.19671 19.30240, -99.19629 19.302...
# 11  POLYGON ((-99.09880 19.32045, -99.09870 19.319...
# 12  POLYGON ((-99.14762 19.40401, -99.14681 19.403...
# 13  POLYGON ((-99.12951 19.46265, -99.12919 19.462...
# 14  POLYGON ((-99.19045 19.47044, -99.19058 19.467...
# 15  POLYGON ((-99.10946 19.45292, -99.10895 19.452...

# %%
df = pd.read_csv('../data/estaciones_ecobici_sist_anterior.csv')
df
# Out:
#      sistema  num_cicloestacion                             nombre  \
# 0    ECOBICI                  1              Río Sena - Río Balsas
# 1    ECOBICI                  2       Río Guadalquivir - Río Nazas
# 2    ECOBICI                  3              Reforma - Insurgentes
# 3    ECOBICI                  4              Río Nilo - Río Pánuco
# 4    ECOBICI                  5             Río Pánuco - Río Tíber
# ..       ...                ...                                ...
# 475  ECOBICI                476       Lago Como - Laguna de Mayrán
# 476  ECOBICI                477       Lago Iseo - Laguna de Mayrán
# 477  ECOBICI                478     Laguna de Mayrán - Lago Chalco
# 478  ECOBICI                479  Lago Muritz - Av. Marina Nacional
# 479  ECOBICI                480    Lago Iseo - Av. Marina Nacional
#
#       calle_principal     calle_secundaria            colonia        alcaldia  \
# 0            Río Sena           Río Balsas         Cuauhtémoc      CUAUHTEMOC
# 1    Río Guadalquivir            Río Nazas         Cuauhtémoc      CUAUHTEMOC
# 2             Reforma          Insurgentes         Tabacalera      CUAUHTEMOC
# 3            Río Nilo           Río Pánuco         Cuauhtémoc      CUAUHTEMOC
# 4          Río Pánuco            Río Tíber         Cuauhtémoc      CUAUHTEMOC
# ..                ...                  ...                ...             ...
# 475         Lago Como     Laguna de Mayrán            Granada  MIGUEL HIDALGO
# 476         Lago Iseo     Laguna de Mayrán  Anáhuac I Sección  MIGUEL HIDALGO
# 477  Laguna de Mayrán          Lago Chalco  Anáhuac I Sección  MIGUEL HIDALGO
# 478       Lago Muritz  Av. Marina Nacional   Mariano Escobedo  MIGUEL HIDALGO
# 479         Lago Iseo  Av. Marina Nacional   Mariano Escobedo  MIGUEL HIDALGO
#
#        latitud   longitud      tipo_ce  candados
# 0    19.433590 -99.167819           4G        27
# 1    19.430510 -99.171201           3G        21
# 2    19.431630 -99.158547           4G        36
# 3    19.428491 -99.171693           3G        15
# 4    19.429804 -99.169451           3G        12
# ..         ...        ...          ...       ...
# 475  19.442127 -99.184433           4G        36
# 476  19.440905 -99.181743           3G        24
# 477  19.440818 -99.176961           3G        27
# 478  19.444433 -99.179664  Multimedial        24
# 479  19.446073 -99.181654           3G        21
#
# [480 rows x 11 columns]

# %%
crs_later = shape.crs

# %%
crs_later
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
shape.to_crs(epsg=6362, inplace=True)
shape.crs
# Out:
# <Projected CRS: EPSG:6362>
# Name: Mexico ITRF92 / LCC
# Axis Info [cartesian]:
# - N[north]: Northing (metre)
# - E[east]: Easting (metre)
# Area of Use:
# - name: Mexico - onshore and offshore.
# - bounds: (-122.19, 12.1, -84.64, 32.72)
# Coordinate Operation:
# - name: Mexico LCC
# - method: Lambert Conic Conformal (2SP)
# Datum: Mexico ITRF92
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
shape['area'] = shape.area / 1000000
shape
# Out:
#    CVEGEO CVE_ENT CVE_MUN                  NOMGEO  \
# 0   09002      09     002            Azcapotzalco
# 1   09003      09     003                Coyoacán
# 2   09004      09     004   Cuajimalpa de Morelos
# 3   09005      09     005       Gustavo A. Madero
# 4   09006      09     006               Iztacalco
# 5   09007      09     007              Iztapalapa
# 6   09008      09     008  La Magdalena Contreras
# 7   09009      09     009              Milpa Alta
# 8   09010      09     010          Álvaro Obregón
# 9   09011      09     011                 Tláhuac
# 10  09012      09     012                 Tlalpan
# 11  09013      09     013              Xochimilco
# 12  09014      09     014           Benito Juárez
# 13  09015      09     015              Cuauhtémoc
# 14  09016      09     016          Miguel Hidalgo
# 15  09017      09     017     Venustiano Carranza
#
#                                              geometry        area
# 0   POLYGON ((2794859.977 837218.408, 2794861.690 ...   33.323092
# 1   POLYGON ((2800218.995 820661.624, 2800250.439 ...   53.622314
# 2   POLYGON ((2787229.790 825329.285, 2787272.744 ...   70.761859
# 3   POLYGON ((2802175.660 843326.718, 2801806.564 ...   87.378306
# 4   POLYGON ((2808145.908 826363.205, 2808144.575 ...   22.962785
# 5   POLYGON ((2812453.035 823708.051, 2812495.143 ...  112.528064
# 6   POLYGON ((2792518.205 818323.067, 2792478.173 ...   63.074767
# 7   POLYGON ((2814877.400 806710.534, 2814871.827 ...  296.728866
# 8   POLYGON ((2794395.922 824857.553, 2794434.245 ...   95.358327
# 9   POLYGON ((2816579.320 817395.961, 2816605.020 ...   85.383283
# 10  POLYGON ((2793795.253 814557.607, 2793840.057 ...  312.852673
# 11  POLYGON ((2804014.964 816753.044, 2804027.680 ...  113.504302
# 12  POLYGON ((2798716.061 825872.886, 2798801.484 ...   26.548923
# 13  POLYGON ((2800483.029 832381.312, 2800517.052 ...   32.335245
# 14  POLYGON ((2794088.523 833114.564, 2794079.895 ...   46.154362
# 15  POLYGON ((2802603.341 831349.500, 2802657.676 ...   33.666050

# %%
shape['boundary'] = shape.boundary
shape
# Out:
#    CVEGEO CVE_ENT CVE_MUN                  NOMGEO  \
# 0   09002      09     002            Azcapotzalco
# 1   09003      09     003                Coyoacán
# 2   09004      09     004   Cuajimalpa de Morelos
# 3   09005      09     005       Gustavo A. Madero
# 4   09006      09     006               Iztacalco
# 5   09007      09     007              Iztapalapa
# 6   09008      09     008  La Magdalena Contreras
# 7   09009      09     009              Milpa Alta
# 8   09010      09     010          Álvaro Obregón
# 9   09011      09     011                 Tláhuac
# 10  09012      09     012                 Tlalpan
# 11  09013      09     013              Xochimilco
# 12  09014      09     014           Benito Juárez
# 13  09015      09     015              Cuauhtémoc
# 14  09016      09     016          Miguel Hidalgo
# 15  09017      09     017     Venustiano Carranza
#
#                                              geometry        area  \
# 0   POLYGON ((2794859.977 837218.408, 2794861.690 ...   33.323092
# 1   POLYGON ((2800218.995 820661.624, 2800250.439 ...   53.622314
# 2   POLYGON ((2787229.790 825329.285, 2787272.744 ...   70.761859
eoDataFrame
gdf = gpd.GeoDataFrame(df, geometry=geometry, crs=crs_later)
shape = shape.to_crs(crs_later)

# %%
# !pip install pygeos
# Out:
# Collecting pygeos
#   Downloading pygeos-0.14-cp39-cp39-win_amd64.whl (1.4 MB)
#      ---------------------------------------- 1.4/1.4 MB 4.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.13 in c:\users\dell\miniconda3\lib\site-packages (from pygeos) (1.21.4)
# Installing collected packages: pygeos
# Successfully installed pygeos-0.14
# [notice] A new release of pip available: 22.2.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pygeos
gpd.options.use_pygeos = True
# Out:
# C:\Users\Dell\miniconda3\lib\site-packages\geopandas\_config.py:104: UserWarning: The Shapely GEOS version (3.10.3-CAPI-1.16.1) is incompatible with the GEOS version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions between both will be slow.
#   compat.set_use_pygeos(value)

# %%
gdf = gpd.sjoin(gdf, shape, how='left', op='within')
# Out:
# C:\Users\Dell\miniconda3\lib\site-packages\IPython\core\interactiveshell.py:3338: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [99], in <cell line: 1>()
# ----> 1 gdf = gpd.sjoin(gdf, shape, how='left', op='within')
#
# File ~\miniconda3\lib\site-packages\geopandas\tools\sjoin.py:121, in sjoin(left_df, right_df, how, predicate, lsuffix, rsuffix, **kwargs)
#     117     raise TypeError(f"sjoin() got an unexpected keyword argument '{first}'")
#     119 _basic_checks(left_df, right_df, how, lsuffix, rsuffix)
# --> 121 indices = _geom_predicate_query(left_df, right_df, predicate)
#     123 joined = _frame_join(indices, left_df, right_df, how, lsuffix, rsuffix)
#     125 return joined
#
# File ~\miniconda3\lib\site-packages\geopandas\tools\sjoin.py:208, in _geom_predicate_query(left_df, right_df, predicate)
#     203 if predicate == "within":
#     204     # within is implemented as the inverse of contains
#     205     # contains is a faster predicate
#     206     # see discussion at https://github.com/geopandas/geopandas/pull/1421
#     207     predicate = "contains"
# --> 208     sindex = left_df.sindex
#     209     input_geoms = right_df.geometry
#     210 else:
#     211     # all other predicates are symmetric
#     212     # keep them the same
#
# File ~\miniconda3\lib\site-packages\geopandas\base.py:3548, in GeoPandasBase.sindex(self)
#    3497 @property
#    3498 def sindex(self):
#    3499     """Generate the spatial index
#    3500
#    3501     Creates R-tree spatial index based on ``pygeos.STRtree`` or
#    (...)
#    3546            [2]])
#    3547     """
# -> 3548     return self.geometry.values.sindex
#
# File ~\miniconda3\lib\site-packages\geopandas\array.py:316, in GeometryArray.sindex(self)
#     313 @property
#     314 def sindex(self):
#     315     if self._sindex is None:
# --> 316         self._sindex = _get_sindex_class()(self._data)
#     317     return self._sindex
#
# File ~\miniconda3\lib\site-packages\geopandas\sindex.py:18, in _get_sindex_class()
#      12 """Dynamically chooses a spatial indexing backend.
#      13
#      14 Required to comply with _compat.USE_PYGEOS.
#      15 The selection order goes PyGEOS > RTree > Error.
#      16 """
#      17 if compat.USE_SHAPELY_20 or compat.USE_PYGEOS:
# ---> 18     return PyGEOSSTRTreeIndex
#      19 if compat.HAS_RTREE:
#      20     return RTreeIndex
#
# NameError: name 'PyGEOSSTRTreeIndex' is not defined

# %%
sudo apt install libspatialindex-dev
# Out:
#   Input In [95]
#     sudo apt install libspatialindex-dev
#          ^
# SyntaxError: invalid syntax
